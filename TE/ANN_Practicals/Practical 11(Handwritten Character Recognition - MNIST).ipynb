# %%
# Plot of images as baseline for comparison 
from tensorflow import keras
from keras.datasets import mnist 
from matplotlib import pyplot 
# load data 
(X_train, y_train), (X_test, y_test) = mnist.load_data() 
# create a grid of 3x3 images 
for i in range(0, 9): 
    pyplot.subplot(330 + 1 + i) 
    pyplot.imshow(X_train[i], cmap=pyplot.get_cmap('gray'))
# show the plot
pyplot.show()

# %%
# Baseline MLP for MNIST dataset
import numpy
from keras.datasets import mnist
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import Dropout
from keras.utils import np_utils

# fix random seed for reproducibility
seed = 7
numpy.random.seed(seed)

# load data
(X_train, y_train), (X_test, y_test) = mnist.load_data()

# flatten 28*28 images to a 784 vector for each image
num_pixels = X_train.shape[1] * X_train.shape[2]
X_train = X_train.reshape(X_train.shape[0], num_pixels).astype('float32')
X_test = X_test.reshape(X_test.shape[0], num_pixels).astype('float32')

# normalize inputs from 0-255 to 0-1
X_train = X_train / 255
X_test = X_test / 255

# one hot encode outputs
y_train = np_utils.to_categorical(y_train)
y_test = np_utils.to_categorical(y_test)
num_classes = y_test.shape[1]

# %%
# define baseline model
def baseline_model():
	# create model
	model = Sequential()
	model.add(Dense(num_pixels, input_dim=num_pixels, kernel_initializer='normal', activation='relu'))
	model.add(Dense(num_classes, kernel_initializer='normal', activation='softmax'))
	# Compile model
	model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
	return model

# %%
# build the model
model = baseline_model()

# Fit the model
model.fit(X_train, y_train, validation_data=(X_test, y_test), epochs=10, batch_size=200, verbose=2)

# Final evaluation of the model
scores = model.evaluate(X_test, y_test, verbose=0)
print("Baseline Error: %.2f%%" % (100-scores[1]*100))
print("\nName : Shantanu Anant Gaikwad\nRoll No : 27")
# Out:
# Epoch 1/10
# 300/300 - 5s - loss: 0.2787 - accuracy: 0.9204 - val_loss: 0.1404 - val_accuracy: 0.9587 - 5s/epoch - 16ms/step
# Epoch 2/10
# 300/300 - 4s - loss: 0.1092 - accuracy: 0.9690 - val_loss: 0.0998 - val_accuracy: 0.9688 - 4s/epoch - 14ms/step
# Epoch 3/10
# 300/300 - 4s - loss: 0.0720 - accuracy: 0.9793 - val_loss: 0.0770 - val_accuracy: 0.9756 - 4s/epoch - 13ms/step
# Epoch 4/10
# 300/300 - 5s - loss: 0.0494 - accuracy: 0.9858 - val_loss: 0.0665 - val_accuracy: 0.9784 - 5s/epoch - 15ms/step
# Epoch 5/10
# 300/300 - 5s - loss: 0.0362 - accuracy: 0.9897 - val_loss: 0.0624 - val_accuracy: 0.9799 - 5s/epoch - 15ms/step
# Epoch 6/10
# 300/300 - 5s - loss: 0.0254 - accuracy: 0.9934 - val_loss: 0.0604 - val_accuracy: 0.9810 - 5s/epoch - 16ms/step
# Epoch 7/10
# 300/300 - 5s - loss: 0.0190 - accuracy: 0.9954 - val_loss: 0.0622 - val_accuracy: 0.9815 - 5s/epoch - 16ms/step
# Epoch 8/10
# 300/300 - 5s - loss: 0.0145 - accuracy: 0.9965 - val_loss: 0.0603 - val_accuracy: 0.9809 - 5s/epoch - 16ms/step
# Epoch 9/10
# 300/300 - 5s - loss: 0.0101 - accuracy: 0.9980 - val_loss: 0.0630 - val_accuracy: 0.9810 - 5s/epoch - 16ms/step
# Epoch 10/10
# 300/300 - 4s - loss: 0.0083 - accuracy: 0.9984 - val_loss: 0.0605 - val_accuracy: 0.9818 - 4s/epoch - 15ms/step
# Baseline Error: 1.82%
#
# Name : Shantanu Anant Gaikwad
# Roll No : 27
